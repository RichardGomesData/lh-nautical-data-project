# %%
import sys
import pandas as pd
import numpy as np

print("Python:", sys.version)
print("Pandas:", pd.__version__)
print("Numpy:", np.__version__)

print("Ambiente OK ✅")
# Out:
# Python: 3.11.15 (main, Apr  9 2026, 22:38:55) [GCC 13.3.0]
# Pandas: 3.0.1
# Numpy: 2.4.3
# Ambiente OK ✅
